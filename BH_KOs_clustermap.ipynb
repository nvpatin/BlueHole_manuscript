# %% [markdown]
# ## This script takes relative abundances of all genes and finds those with the biggest difference between 60m and Deep metagenomes (calculated as the absolute value of difference in means). Then a heat map of these genes is generated using the Seaborn clustermap function.

# %%
import os as os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Navigate to directory containing read counts file
os.chdir("/Users/nastassia.patin/Desktop/Projects/BlueHole/ISMEJ_revisions/")
path = "60Ms_vs_deeps_KOs_readcounts.csv"

# %%
df = pd.read_csv(path)
df.head()
# Out:
#         Group                                     Subgroup  \
# 0  Metabolism                      Carbohydrate metabolism
# 1  Metabolism                      Carbohydrate metabolism
# 2  Metabolism                      Carbohydrate metabolism
# 3  Metabolism                      Carbohydrate metabolism
# 4  Metabolism  Biosynthesis of other secondary metabolites
#
#                                            Subgroup2      KO  \
# 0        Glycolysis / Gluconeogenesis [PATH:ko00010]  K00845
# 1                Galactose metabolism [PATH:ko00052]  K00845
# 2       Starch and sucrose metabolism [PATH:ko00500]  K00845
# 3  Amino sugar and nucleotide sugar metabolism [P...  K00845
# 4           Streptomycin biosynthesis [PATH:ko00521]  K00845
#
#                          Function  ReadCounts     Sample      GE  \
# 0   glk; glucokinase [EC:2.7.1.2]         629  BH091960M  2401.2
# 1   glk; glucokinase [EC:2.7.1.2]         629  BH091960M  2401.2
# 2   glk; glucokinase [EC:2.7.1.2]         629  BH091960M  2401.2
# 3   glk; glucokinase [EC:2.7.1.2]         629  BH091960M  2401.2
# 4   glk; glucokinase [EC:2.7.1.2]         629  BH091960M  2401.2
#
#    ReadCounts_Norm dataset
# 0         0.261952    60Ms
# 1         0.261952    60Ms
# 2         0.261952    60Ms
# 3         0.261952    60Ms
# 4         0.261952    60Ms

# %%
# Exclude irrelevant KEGG categories
df = df.loc[(df['Group'] != 'Human Diseases') & 
               (df['Group'] != 'Brite Hierarchies') & 
               (df['Group'] != 'Organismal Systems') &
               (df['Subgroup'] != 'Cellular community - eukaryotes')]

# %% [markdown]
# ### For KOs, drop duplicates
# #### Some genes will belong to multiple categories, but we don't want to count them twice

# %%
df2 = df.sort_values('ReadCounts_Norm').drop_duplicates(subset=['Sample', 'KO'], keep='last')
df2 = df2.reset_index(drop=True)
df2.head()
# Out:
#                                   Group  \
# 0                            Metabolism
# 1                            Metabolism
# 2      Not Included in Pathway or Brite
# 3  Environmental Information Processing
# 4      Not Included in Pathway or Brite
#
#                                        Subgroup  \
# 0                       Carbohydrate metabolism
# 1                         Amino acid metabolism
# 2                          Poorly characterized
# 3                           Signal transduction
# 4  Unclassified: genetic information processing
#
#                                    Subgroup2      KO  \
# 0                       Pyruvate metabolism   K01573
# 1  Glycine, serine and threonine metabolism   K06720
# 2                           Function unknown  K09991
# 3                      Two-component system   K13588
# 4                         Protein processing  K19411
#
#                                             Function  ReadCounts     Sample  \
# 0   oadG; oxaloacetate decarboxylase (Na+ extrudi...           1  BH091995M
# 1            ectC; L-ectoine synthase [EC:4.2.1.108]           1  BH091995M
# 2                    K09991; uncharacterized protein           2  BH091960M
# 3            chpT; histidine phosphotransferase ChpT           2  BH091960M
# 4            mcsA; protein arginine kinase activator           2  BH091960M
#
#        GE  ReadCounts_Norm dataset
# 0  1283.9         0.000779   deeps
# 1  1283.9         0.000779   deeps
# 2  2401.2         0.000833    60Ms
# 3  2401.2         0.000833    60Ms
# 4  2401.2         0.000833    60Ms

# %%
# Get a distribution of read counts
ax = df2['ReadCounts_Norm'].plot.hist(bins=50, alpha=1)

# %% [markdown]
# ### Split the data frame by dataset

# %%
df_G1 = df2.loc[(df2['dataset'] == '60Ms')]
df_G2 = df2.loc[(df2['dataset'] == 'deeps')]

# %%
df_G1_sub = df_G1[['KO','Sample','ReadCounts_Norm']]
df_G2_sub = df_G2[['KO','Sample','ReadCounts_Norm']]

# %% [markdown]
# ### Concatenate the two data sets while maintaining the information as to which row is from which data set

# %%
concat = pd.concat([df_G1_sub.assign(dataset='60Ms'), df_G2_sub.assign(dataset='Deeps')])
concat.head()
# Out:
#        KO     Sample  ReadCounts_Norm dataset
# 2  K09991  BH091960M         0.000833    60Ms
# 3  K13588  BH091960M         0.000833    60Ms
# 4  K19411  BH091960M         0.000833    60Ms
# 5  K15761  BH091960M         0.001249    60Ms
# 6  K08973       BH37         0.001520    60Ms

# %%
# Reformat data frame for heat map
df4 = pd.pivot_table(data=concat, index='Sample', values='ReadCounts_Norm', columns='KO')
df4 = df4.fillna(0).reindex(["BH37","BH091960M","BH51","BH091995M"])
df4.head()
# Out:
# KO           K00003    K00005    K00009    K00010    K00012    K00013  \
# Sample
# BH37       1.358456  0.000000  0.000000  0.308464  0.512080  0.743048
# BH091960M  0.592620  0.000000  0.000000  0.084541  0.534733  0.415209
# BH51       1.137606  0.000000  0.000000  0.072032  0.444610  1.043219
# BH091995M  0.840408  0.053743  0.031155  0.031155  1.314744  0.498481
#
# KO           K00014    K00015    K00016    K00018  ...    K23492    K23508  \
# Sample                                             ...
# BH37       0.761282  0.057742  0.000000  0.217292  ...  0.000000  0.000000
# BH091960M  0.906630  0.034150  0.000000  0.285274  ...  0.016242  0.000000
# BH51       1.140089  0.094386  0.000000  0.057129  ...  0.000000  0.000000
# BH091995M  0.774204  0.056858  0.014799  0.071657  ...  0.000000  0.022587
#
# KO           K23514    K23518    K23535    K23536    K23537    K23548  \
# Sample
# BH37       0.000000  0.000000  0.945145  0.791673  1.186750  0.000000
# BH091960M  0.032067  0.052057  0.853323  1.465517  0.294436  0.000000
# BH51       0.074516  0.074516  0.000000  0.000000  0.146547  0.000000
# BH091995M  0.116832  0.038165  0.147987  0.153439  0.232884  0.102033
#
# KO           K23549    K23573
# Sample
# BH37       0.000000  0.000000
# BH091960M  0.000000  0.018741
# BH51       0.176354  1.266766
# BH091995M  0.131630  2.562505
#
# [4 rows x 3374 columns]

# %% [markdown]
# ### Calculate the fold difference between sample pairs

# %%
def fold_difference(a, b, c, d):
    diff = ((a + b)/2) / ((c + d)/2)
    return(diff)

# %%
df4 = df4.replace(0, 0.000000001)
df4 = df4.append(pd.Series(name='Average'))
df4 = df4.append(pd.Series(name='Fold difference', dtype='float64'))
df4.loc['Average'] = np.array(np.mean(df4.iloc[:3, :], axis=0))
df4.loc['Fold difference'] = df4.apply(lambda x: 
                                           fold_difference(x.loc['BH37'], x.loc['BH091960M'], 
                                                           x.loc['BH51'], x.loc['BH091995M']), axis=0)
df4.head(6)
# Out:
# <ipython-input-14-00ed9ada64a9>:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   df4 = df4.append(pd.Series(name='Average'))
# KO                 K00003        K00005        K00009    K00010    K00012  \
# Sample
# BH37             1.358456  1.000000e-09  1.000000e-09  0.308464  0.512080
# BH091960M        0.592620  1.000000e-09  1.000000e-09  0.084541  0.534733
# BH51             1.137606  1.000000e-09  1.000000e-09  0.072032  0.444610
# BH091995M        0.840408  5.374250e-02  3.115507e-02  0.031155  1.314744
# Average          1.029561  1.000000e-09  1.000000e-09  0.155012  0.497141
# Fold difference  0.986382  3.721449e-08  6.419500e-08  3.808671  0.594998
#
# KO                 K00013    K00014    K00015        K00016    K00018  ...  \
# Sample                                                                 ...
# BH37             0.743048  0.761282  0.057742  1.000000e-09  0.217292  ...
# BH091960M        0.415209  0.906630  0.034150  1.000000e-09  0.285274  ...
# BH51             1.043219  1.140089  0.094386  1.000000e-09  0.057129  ...
# BH091995M        0.498481  0.774204  0.056858  1.479866e-02  0.071657  ...
# Average          0.733825  0.936001  0.062093  1.000000e-09  0.186565  ...
# Fold difference  0.751286  0.871294  0.607570  1.351474e-07  3.902356  ...
#
# KO                     K23492        K23508        K23514        K23518  \
# Sample
# BH37             1.000000e-09  1.000000e-09  1.000000e-09  1.000000e-09
# BH091960M        1.624188e-02  1.000000e-09  3.206730e-02  5.205730e-02
# BH51             1.000000e-09  1.000000e-09  7.451565e-02  7.451565e-02
# BH091995M        1.000000e-09  2.258743e-02  1.168315e-01  3.816497e-02
# Average          5.413960e-03  1.000000e-09  3.552765e-02  4.219098e-02
# Fold difference  8.120940e+06  8.854482e-08  1.675870e-01  4.619899e-01
#
# KO                     K23535        K23536    K23537        K23548  \
# Sample
# BH37             9.451451e-01  7.916730e-01  1.186750  1.000000e-09
# BH091960M        8.533233e-01  1.465517e+00  0.294436  1.000000e-09
# BH51             1.000000e-09  1.000000e-09  0.146547  1.000000e-09
# BH091995M        1.479866e-01  1.534387e-01  0.232884  1.020329e-01
# Average          5.994895e-01  7.523967e-01  0.542578  1.000000e-09
# Fold difference  1.215291e+01  1.471069e+01  3.903696  1.960153e-08
#
# KO                     K23549        K23573
# Sample
# BH37             1.000000e-09  1.000000e-09
# BH091960M        1.000000e-09  1.874063e-02
# BH51             1.763537e-01  1.266766e+00
# BH091995M        1.316302e-01  2.562505e+00
# Average          5.878457e-02  4.285022e-01
# Fold difference  6.493846e-09  4.894047e-03
#
# [6 rows x 3374 columns]

# %% [markdown]
# ### Get the distribution of average normalized read counts across all samples

# %%
ax = df4.loc['Average'].plot.hist(bins=50, alpha=1)

# %% [markdown]
# ### Select only the columns (KOs) with an average relative abundnace above 0.2 and a twenty-fold or greater difference

# %%
df5 = df4.loc[:, ((df4.loc['Average'] > 0.2) & 
                  ((df4.loc['Fold difference'] < 0.05) | (df4.loc['Fold difference'] > 20)))]
df5.shape

# %%
df5 = df5.sort_values(by='Fold difference', axis=1)
df5.head()

# %%
# Get average and fold difference values for K25373
df5['K23573']
# Out:
# Sample
# BH37               1.000000e-09
# BH091960M          1.874063e-02
# BH51               1.266766e+00
# BH091995M          2.562505e+00
# Average            4.285022e-01
# Fold difference    4.894047e-03
# Name: K23573, dtype: float64

# %%
# Just get the sample rows
df6 = df5.iloc[0:4, :]
df6.head()
# Out:
# KO               K05349        K02567        K07716        K11942  \
# Sample
# BH37       1.000000e-09  1.000000e-09  1.000000e-09  1.000000e-09
# BH091960M  1.000000e-09  1.000000e-09  1.000000e-09  1.000000e-09
# BH51       6.756085e-01  3.060109e+00  2.071535e+00  7.973174e-01
# BH091995M  4.618740e+00  9.253057e-01  9.790482e-01  1.671470e+00
#
# KO               K06959        K13040        K05367        K07641  \
# Sample
# BH37       1.000000e-09  1.000000e-09  1.000000e-09  1.000000e-09
# BH091960M  1.000000e-09  1.000000e-09  1.000000e-09  1.000000e-09
# BH51       6.209637e-01  1.671634e+00  6.135122e-01  1.403378e+00
# BH091995M  1.336553e+00  8.801309e-02  1.084197e+00  2.102968e-02
#
# KO               K04561        K02319  ...        K02182        K09472  \
# Sample                                 ...
# BH37       1.000000e-09  1.000000e-09  ...  6.154080e-01  6.321228e-01
# BH091960M  1.000000e-09  1.000000e-09  ...  3.452440e-01  3.960520e-01
# BH51       1.239444e+00  9.612519e-01  ...  1.000000e-09  1.000000e-09
# BH091995M  8.411870e-02  1.386401e-01  ...  1.000000e-09  1.000000e-09
#
# KO               K18593        K03338        K07577        K06954  \
# Sample
# BH37       1.066707e+00  1.098617e+00  1.021121e+00  7.582434e-01
# BH091960M  1.000000e-09  1.415959e-02  1.465934e-01  4.193736e-01
# BH51       1.000000e-09  1.000000e-09  1.000000e-09  1.000000e-09
# BH091995M  1.000000e-09  1.000000e-09  1.000000e-09  1.000000e-09
#
# KO               K14260        K22187        K23464        K01637
# Sample
# BH37       7.308920e-01  1.189789e+00  1.083422e+00  1.340222e+00
# BH091960M  5.234883e-01  1.961519e-01  5.805431e-01  1.033233e+00
# BH51       1.000000e-09  1.000000e-09  1.000000e-09  1.000000e-09
# BH091995M  1.000000e-09  1.000000e-09  1.000000e-09  1.000000e-09
#
# [4 rows x 101 columns]

# %% [markdown]
# ### Match KOs with KEGG Groups

# %%
kos = list(df6.columns.values)

# %%
df6_func = df2.loc[df2['KO'].str.fullmatch('|'.join(kos))]
df6_func = df6_func[['Group','KO']]
df6_func = df6_func.drop_duplicates()
df6_func.shape
# Out:
# (106, 2)

# %% [markdown]
# #### Transform values as needed for a nice visual

# %%
df6_log = np.log(df6)
df6_sqrt = np.sqrt(df6)
df6_frthrt = np.sqrt(df6_sqrt)

# %% [markdown]
# #### Make color bar for heat map

# %%
lut = dict(zip(df6_func['Group'].unique(), 
                sns.color_palette("Paired")))
lut
# Out:
# {'Metabolism': (0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  'Not Included in Pathway or Brite': (0.12156862745098039,
#   0.47058823529411764,
#   0.7058823529411765),
#  'Environmental Information Processing': (0.6980392156862745,
#   0.8745098039215686,
#   0.5411764705882353),
#  'Genetic Information Processing': (0.2,
#   0.6274509803921569,
#   0.17254901960784313),
#  'Cellular Processes': (0.984313725490196, 0.6039215686274509, 0.6)}

# %%
df6_func['Color'] = df6_func['Group'].map(lut)
df6_func.shape
# Out:
# (106, 3)

# %%
lut3 = dict(zip(df6_func['KO'], df6_func['Color']))
column_colors = pd.Series(lut3)

# %%
lut3
# Out:
# {'K02568': (0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  'K07182': (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  'K02305': (0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  'K03281': (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  'K01434': (0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  'K05815': (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  'K03338': (0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  'K06863': (0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  'K08299': (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  'K03851': (0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  'K17241': (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  'K08975': (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  'K23573': (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  'K18277': (0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  'K18682': (0.2, 0.6274509803921569, 0.17254901960784313),
#  'K07641': (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  'K17315': (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  'K01623': (0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  'K12256': (0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  'K00425': (0.6509803921568628, 0.807843137254902, 0.8901960784313725),
#  'K09703': (0.12156862745098039, 0.47058823529411764, 0.7058823529411765),
#  'K11710': (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
#  'K11074': (0.6980392156862745, 0.8745098039215686, 0.5411764705882353),
# %%
column_colors
# Out:
# K02568    (0.6509803921568628, 0.807843137254902, 0.8901...
# K07182    (0.12156862745098039, 0.47058823529411764, 0.7...
# K02305    (0.6509803921568628, 0.807843137254902, 0.8901...
# K03281    (0.12156862745098039, 0.47058823529411764, 0.7...
# K01434    (0.6509803921568628, 0.807843137254902, 0.8901...
#                                 ...
# K12308    (0.6509803921568628, 0.807843137254902, 0.8901...
# K02567    (0.6509803921568628, 0.807843137254902, 0.8901...
# K07716    (0.6980392156862745, 0.8745098039215686, 0.541...
# K01637    (0.6509803921568628, 0.807843137254902, 0.8901...
# K18593    (0.6509803921568628, 0.807843137254902, 0.8901...
# Length: 101, dtype: object

# %% [markdown]
# ### Set palette for color bar

# %%
my_palette = dict(zip(concat.dataset.unique(), ["purple","orange"]))
row_colors = concat.dataset.map(my_palette)
sampz = concat.Sample

# %%
sample_colors = sampz.to_frame().join(row_colors)
sample_colors = sample_colors.drop_duplicates(subset=['Sample'])
sample_colors = sample_colors.set_index('Sample')
sample_colors.head()
# Out:
#           dataset
# Sample
# BH091960M  purple
# BH37       purple
# BH091995M  orange
# BH51       orange

# %% [markdown]
# ## Make the clustermap

# %%
p = sns.clustermap(df6_frthrt, cmap='YlGnBu', figsize=(20,10), xticklabels=True, method='ward',
                   metric='euclidean', row_colors = sample_colors, col_colors=column_colors)

# %%
p = sns.clustermap(df6_frthrt, cmap='YlGnBu', method='ward', metric='euclidean', xticklabels=True, row_cluster=False,
                   col_cluster=False, yticklabels=False, row_colors = sample_colors, col_colors = column_colors)
hm = p.ax_heatmap.get_position()
#col = p.ax_col_dendrogram.get_position()
#p.ax_heatmap.invert_yaxis()
#plt.setp(p.ax_heatmap.yaxis.get_majorticklabels(), fontsize=18)
#plt.setp(p.ax_heatmap.xaxis.get_majorticklabels(), fontsize=22)
#plt.setp(p.ax_heatmap.yaxis.invert())
p.ax_heatmap.set_position([hm.x0, hm.y0, hm.width*3, hm.height])
p.ax_col_colors.set_position([col.x0, col.y0-0.04, col.width*3, col.height*0.25])
row = p.ax_row_dendrogram.get_position()
#p.ax_col_dendrogram.set_position([col.x0, col.y0, col.width*3, col.height*0.5])
p.ax_row_dendrogram.set_position([row.x0+0.07, row.y0, row.width*0.75, row.height])
p.ax_heatmap.set_xticklabels(p.ax_heatmap.get_xmajorticklabels(), fontsize = 16)
p.ax_col_dendrogram.set_visible(False)

# %%
p.savefig("FigS6B_new2_KOs.png")

# %% [markdown]
# ### Make a separate legend for the KEGG category color bar

# %%
x, y = (0.1, 0)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
for func in df6_func['Group'].unique():
    y = y + 0.1
    color = lut[func]
    square = plt.Rectangle((x, y), 0.1, 0.1, fc=color)
    plt.gca().add_patch(square)
    plt.text(x + 0.12, y + 0.03, func, fontsize=12)

# %%
fig.savefig('FigS6B_legend.png')
